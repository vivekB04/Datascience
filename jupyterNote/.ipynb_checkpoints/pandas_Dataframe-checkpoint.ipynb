# %%
import pandas as pd

# %%
data={
    "Name":["Ashish","Rahul","Kanha"],
    "Age":[23,25,22]
}
df= pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0  Ashish   23
# 1   Rahul   25
# 2   Kanha   22
